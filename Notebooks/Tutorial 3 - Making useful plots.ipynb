# %%
import packerlabimaging as pkg
import packerlabimaging.plotting as plotting
# Out:
# ...
# No module named 'cellpose'
# cannot use anatomical mode, but otherwise suite2p will run normally
#
# imported packerlabimaging
# 	version: under...alpha...development

# %%
# import data trialobj (TwoPhotonImaging Trial object)

expobj = pkg.import_obj(pkl_path='/home/pshah/Documents/code/packerlabimaging/tests/RL109_analysis.pkl')
print(expobj)
trialobj = expobj.load_trial(trialID='t-013')
# Out:
# |- Loaded packerlabimaging.Experiment object (date: 2020-12-19, expID: RL109)kl ...
# packerlabimaging Experiment object (last saved: Fri Feb 11 20:34:47 2022), date: 2020-12-19, expID: RL109, microscope: Bruker
# file path: /home/pshah/Documents/code/packerlabimaging/tests/RL109_analysis.pkl
#
# trials in Experiment object:
# 	t-005: TwoPhotonImagingTrial, pre 4ap 2p spont imaging
# 	t-006: TwoPhotonImagingTrial, pre 4ap 2p spont imaging
# 	t-013: AllOpticalTrial, pre 4ap 2p all optical
#
# |- Loaded (RL109 t-013) TwoPhotonImagingTrial.alloptical experimental trial object, last saved: Tue Feb  8 00:12:01 2022

# %%
# simple plot of the location of the given cell(s) against a black FOV (optionally provide background image as np.array to use)
plotting.plotRoiLocations(trialobj)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_43618/1766851500.py in <module>
#       1 # simple plot of the location of the given cell(s) against a black FOV (optionally provide background image as np.array to use)
# ----> 2 plotting.plotRoiLocations(trialobj)
#
# TypeError: inner() takes 0 positional arguments but 1 was given

# %%
# plot default output images from Suite2p
plotting.makeSuite2pPlots(expobj)

# %%
# (full) plot individual cell's flu or dFF trace, with photostim. timings for that cell
import numpy as np
plotting.plot_flu_trace(trialobj, cell=np.random.choice(len(trialobj.Suite2p.cell_id)), to_plot = 'raw', linewidth = 0.10,
                        x_lims=None, y_lims= None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_43618/3788491730.py in <module>
#       1 # (full) plot individual cell's flu or dFF trace, with photostim. timings for that cell
#       2 import numpy as np
# ----> 3 plotting.plot_flu_trace(trialobj, cell=np.random.choice(len(trialobj.Suite2p.cell_id)), to_plot = 'raw', linewidth = 0.10,
#       4                         x_lims=None, y_lims= None)
#
# TypeError: object of type 'int' has no len()

# %%
# Out:
# 0

# %%
import os

# %%
os.getcwd()

# %%
from IPython import display
display.Image("files/TwoPhoton Imaging Workflow #1.png")

# %%
from packerlabimaging.imaging_utils import *

# %%
from packerlabimaging import imaging_utils as iu
expobj = iu.TwoPhotonImaging(...)

# %%
metainfo = {
    'animal prep.': 'RL109',
    'trial': 't-013',
    't series id': 'RL109 t-013',
    'date': '2020-12-19',
    'exptype': 'pre 4ap 2p all optical',
    'comments': '<comments about the experiment>'
}


tiff_path = '/home/pshah/mnt/qnap/Data/2020-12-19/2020-12-19_t-013/2020-12-19_t-013_Cycle00001_Ch3.tif'
paq_path = '/home/pshah/mnt/qnap/Data/2020-12-19/2020-12-19_RL109_013.paq'
analysis_save_path = '/home/pshah/Documents/code/packerlabimaging/tests/'
suite2p_path = None

expobj = TwoPhotonImaging(tiff_path=tiff_path, exp_metainfo=metainfo, analysis_save_path=analysis_save_path,
                 paq_path=paq_path, suite2p_path=suite2p_path, make_downsampled_tiff=False)
# Out:
# ***** CREATING NEW TwoPhotonImaging with the following exp_metainfo:  {'animal prep.': 'RL109', 'trial': 't-013', 'date': '2020-12-19', 'exptype': 'pre 4ap 2p all optical', 'comments': '<comments about the experiment>'}
#
# 	 -- data object saved to /home/pshah/Documents/code/packerlabimaging/tests/2020-12-19_t-013.pkl --
#
# -----parsing PV Metadata
# n planes: 1
# n frames: 16368
# fps: 30.189722784380017
# frame size (px): 512 x 512
# zoom: 1.0
# pixel size (um): 2.18458479264539 2.18458479264539
# scan centre (V): 0.0 0.0
#
#
# -----processing paq file...
# |- loading paq data from: /home/pshah/mnt/qnap/Data/2020-12-19/2020-12-19_RL109_013.paq
# 	 -- data object saved to /home/pshah/Documents/code/packerlabimaging/tests/2020-12-19_t-013.pkl --

# %%
expobj
# Out:
# '(RL109 t-013) TwoPhotonImaging experimental data object, last saved: Sun Dec  5 16:04:13 2021'

# %%
_ = expobj.plot_single_frame_tiff(frame_num=10)
